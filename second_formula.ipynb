# %%
import pandas as pd
from nltk.tokenize import word_tokenize
import nltk
import pprint

# %%
df = pd.read_csv("slurs_annotated_data.csv")

# %%
df
# Out:
#        Unnamed: 0      rapper                                song    year  \
# 0               0      Cordae                                 RNP  2019.0
# 1               1      Cordae                             Kung Fu  2018.0
# 2               2      Cordae                            Bad Idea  2019.0
# 3               3      Cordae                          Have Mercy  2019.0
# 4               4      Cordae                          Old Niggas  2018.0
# ...           ...         ...                                 ...     ...
# 15382       15382  André 3000                         Pink & Blue  2003.0
# 15383       15383  André 3000  Chronomentrophobia (Movie Version)  2006.0
# 15384       15384  André 3000                       Back to Black     NaN
# 15385       15385  André 3000                         Crayon Song     NaN
# 15386       15386  André 3000            Hey Ya! - Single Version  2003.0
#
#                                                   lyrics  \
# 0      Uh, okay, put your fucking hands up, this the ...
# 1      I'ma just get it and get it again\nCome ups I ...
# 2      I know myself all too well to be a stranger of...
# 3      There's no complainin' on this side\nMy niggas...
# 4      Uh, old niggas and new niggas, now what's the ...
# ...                                                  ...
# 15382  Miss lady\nYou could have been born a little l...
# 15383  High's the cost of living\nI take what I have ...
# 15384  I, I, I left no time to regret\nKept my dick w...
# 15385  Black or blue, purple or yellow\nOr red\nSee, ...
# 15386  My baby don't mess around\nBecause she loves m...
#
#                                          lyrics_splitted  \
# 0      Uh, okay, put your fucking hands up, this the ...
# 1      I'ma just get it and get it again Come ups I s...
# 2      I know myself all too well to be a stranger of...
# 3      There's no complainin' on this side My niggas,...
# 4      Uh, old niggas and new niggas, now what's the ...
# ...                                                  ...
# 15382  Miss lady You could have been born a little la...
# 15383  High's the cost of living I take what I have b...
# 15384  I, I, I left no time to regret Kept my dick we...
# 15385  Black or blue, purple or yellow Or red See, we...
# 15386  My baby don't mess around Because she loves me...
#
#                                    lyrics_splitted_lines  \
# 0      ['Uh, okay, put your fucking hands up, this th...
# 1      ["I'ma just get it and get it again", 'Come up...
# 2      ['I know myself all too well to be a stranger ...
# 3      ["There's no complainin' on this side", 'My ni...
# 4      ["Uh, old niggas and new niggas, now what's th...
# ...                                                  ...
# 15382  ['Miss lady', "You could have been born a litt...
# 15383  ["High's the cost of living", 'I take what I h...
# 15384  ['I, I, I left no time to regret', 'Kept my di...
# 15385  ['Black or blue, purple or yellow', 'Or red', ...
# 15386  ["My baby don't mess around", 'Because she lov...
#
#                                         lyrics_tokenized  \
# 0      Uh , okay , put your fucking hands up , this t...
# 1      I'ma just get it and get it again Come ups I s...
# 2      I know myself all too well to be a stranger of...
# 3      There 's no complainin ' on this side My nigga...
# 4      Uh , old niggas and new niggas , now what 's t...
# ...                                                  ...
# 15382  Miss lady You could have been born a little la...
# 15383  High 's the cost of living I take what I have ...
# 15384  I , I , I left no time to regret Kept my dick ...
# 15385  Black or blue , purple or yellow Or red See , ...
# 15386  My baby do n't mess around Because she loves m...
#
#                                        lyrics_lemmatized  formula_num_sent  \
# 0      ['Uh', ',', 'okay', ',', 'put', 'your', 'fucki...                30
# 1      ["I'ma", 'just', 'get', 'it', 'and', 'get', 'i...                37
# 2      ['I', 'know', 'myself', 'all', 'too', 'well', ...                44
# 3      ['There', "'s", 'no', 'complainin', "'", 'on',...                33
# 4      ['Uh', ',', 'old', 'nigga', 'and', 'new', 'nig...                63
# ...                                                  ...               ...
# 15382  ['Miss', 'lady', 'You', 'could', 'have', 'been...                31
# 15383  ['High', "'s", 'the', 'cost', 'of', 'living', ...                32
# 15384  ['I', ',', 'I', ',', 'I', 'left', 'no', 'time'...                14
# 15385  ['Black', 'or', 'blue', ',', 'purple', 'or', '...                 7
# 15386  ['My', 'baby', 'do', "n't", 'mess', 'around', ...                17
#
#                                                    slurs  num_slurs  \
# 0      ['nigga', 'fucking', 'bitch', 'Fuck', 'motherf...        5.0
# 1      ['nigga', 'fucking', 'fucked', 'bitch', 'godda...        5.0
# 2                                      ['nigga', 'shit']        2.0
# 3                     ['nigga', 'bitch', 'Fuck', 'shit']        4.0
# 4                ['bullshit', 'suck', 'fuckin', 'nigga']        4.0
# ...                                                  ...        ...
# 15382                                                 []        0.0
# 15383                                          ['nigga']        1.0
# 15384                                                 []        0.0
# 15385                                                 []        0.0
# 15386                                                 []        0.0
#
#        formula_song
# 0          0.006905
# 1          0.005893
# 2          0.001683
# 3          0.005062
# 4          0.002265
# ...             ...
# 15382      0.000000
# 15383      0.002367
# 15384      0.000000
# 15385      0.000000
# 15386      0.000000
#
# [15387 rows x 13 columns]

# %%
df_slurs = pd.read_csv("slurs.csv", sep=";")

# %%
slurs = dict(zip(df_slurs.text, df_slurs.severity_rating))

# %%
def count_sev_score_lyrics(df_line): 
        
    lst = df_line.split("\n") # split lyrics into lines
    num_lines = len(lst) # number of lines
    token_lines = [word_tokenize(s) for s in lst]
    scores_for_sent = {}
    weighted_sev_score_lyrics = 0  # value for averaged sev_score over the whole lyrics

    for i,line in enumerate(token_lines):
        num_of_words = len(line) # number of words in one line
        sev_score_line = 0  # sev score for one line
        for el in line:
            if el in slurs:
                sev_score_line += float(slurs[el])  
        weighted_sev_score = sev_score_line/num_of_words   # weighted sev score for one line
        scores_for_sent[i] = {"num_of_words": num_of_words, "sev_score_per_line": sev_score_line, "weighted_sev_score": weighted_sev_score}
        weighted_sev_score_lyrics += weighted_sev_score # we sum all the weighted sev scores for each line

    result = weighted_sev_score_lyrics/num_lines # get the intended value (average sev score for lyrics divided by number of lines

    #pprint.pprint(scores_for_sent)
    return result

# %%
df["formula_2_lyrics"] = df["lyrics"].apply(lambda x: count_sev_score_lyrics(x))

# %%
df
# Out:
#        Unnamed: 0      rapper                                song    year  \
# 0               0      Cordae                                 RNP  2019.0
# 1               1      Cordae                             Kung Fu  2018.0
# 2               2      Cordae                            Bad Idea  2019.0
# 3               3      Cordae                          Have Mercy  2019.0
# 4               4      Cordae                          Old Niggas  2018.0
# ...           ...         ...                                 ...     ...
# 15382       15382  André 3000                         Pink & Blue  2003.0
# 15383       15383  André 3000  Chronomentrophobia (Movie Version)  2006.0
# 15384       15384  André 3000                       Back to Black     NaN
# 15385       15385  André 3000                         Crayon Song     NaN
# 15386       15386  André 3000            Hey Ya! - Single Version  2003.0
#
#                                                   lyrics  \
# 0      Uh, okay, put your fucking hands up, this the ...
# 1      I'ma just get it and get it again\nCome ups I ...
# 2      I know myself all too well to be a stranger of...
# 3      There's no complainin' on this side\nMy niggas...
# 4      Uh, old niggas and new niggas, now what's the ...
# ...                                                  ...
# 15382  Miss lady\nYou could have been born a little l...
# 15383  High's the cost of living\nI take what I have ...
# 15384  I, I, I left no time to regret\nKept my dick w...
# 15385  Black or blue, purple or yellow\nOr red\nSee, ...
# 15386  My baby don't mess around\nBecause she loves m...
#
#                                          lyrics_splitted  \
# 0      Uh, okay, put your fucking hands up, this the ...
# 1      I'ma just get it and get it again Come ups I s...
# 2      I know myself all too well to be a stranger of...
# 3      There's no complainin' on this side My niggas,...
# 4      Uh, old niggas and new niggas, now what's the ...
# ...                                                  ...
# 15382  Miss lady You could have been born a little la...
# 15383  High's the cost of living I take what I have b...
# 15384  I, I, I left no time to regret Kept my dick we...
# 15385  Black or blue, purple or yellow Or red See, we...
# 15386  My baby don't mess around Because she loves me...
#
#                                    lyrics_splitted_lines  \
# 0      ['Uh, okay, put your fucking hands up, this th...
# 1      ["I'ma just get it and get it again", 'Come up...
# 2      ['I know myself all too well to be a stranger ...
# 3      ["There's no complainin' on this side", 'My ni...
# 4      ["Uh, old niggas and new niggas, now what's th...
# ...                                                  ...
# 15382  ['Miss lady', "You could have been born a litt...
# 15383  ["High's the cost of living", 'I take what I h...
# 15384  ['I, I, I left no time to regret', 'Kept my di...
# 15385  ['Black or blue, purple or yellow', 'Or red', ...
# 15386  ["My baby don't mess around", 'Because she lov...
#
#                                         lyrics_tokenized  \
# 0      Uh , okay , put your fucking hands up , this t...
# 1      I'ma just get it and get it again Come ups I s...
# 2      I know myself all too well to be a stranger of...
# 3      There 's no complainin ' on this side My nigga...
# 4      Uh , old niggas and new niggas , now what 's t...
# ...                                                  ...
# 15382  Miss lady You could have been born a little la...
# 15383  High 's the cost of living I take what I have ...
# 15384  I , I , I left no time to regret Kept my dick ...
# 15385  Black or blue , purple or yellow Or red See , ...
# 15386  My baby do n't mess around Because she loves m...
#
#                                        lyrics_lemmatized  formula_num_sent  \
# 0      ['Uh', ',', 'okay', ',', 'put', 'your', 'fucki...                30
# 1      ["I'ma", 'just', 'get', 'it', 'and', 'get', 'i...                37
# 2      ['I', 'know', 'myself', 'all', 'too', 'well', ...                44
# 3      ['There', "'s", 'no', 'complainin', "'", 'on',...                33
# 4      ['Uh', ',', 'old', 'nigga', 'and', 'new', 'nig...                63
# ...                                                  ...               ...
# 15382  ['Miss', 'lady', 'You', 'could', 'have', 'been...                31
# 15383  ['High', "'s", 'the', 'cost', 'of', 'living', ...                32
# 15384  ['I', ',', 'I', ',', 'I', 'left', 'no', 'time'...                14
# 15385  ['Black', 'or', 'blue', ',', 'purple', 'or', '...                 7
# 15386  ['My', 'baby', 'do', "n't", 'mess', 'around', ...                17
#
#                                                    slurs  num_slurs  \
# 0      ['nigga', 'fucking', 'bitch', 'Fuck', 'motherf...        5.0
# 1      ['nigga', 'fucking', 'fucked', 'bitch', 'godda...        5.0
# 2                                      ['nigga', 'shit']        2.0
# 3                     ['nigga', 'bitch', 'Fuck', 'shit']        4.0
# 4                ['bullshit', 'suck', 'fuckin', 'nigga']        4.0
# ...                                                  ...        ...
# 15382                                                 []        0.0
# 15383                                          ['nigga']        1.0
# 15384                                                 []        0.0
# 15385                                                 []        0.0
# 15386                                                 []        0.0
#
#        formula_song  formula_2_lyrics
# 0          0.006905          0.047971
# 1          0.005893          0.067862
# 2          0.001683          0.040731
# 3          0.005062          0.079808
# 4          0.002265          0.074943
# ...             ...               ...
# 15382      0.000000          0.000000
# 15383      0.002367          0.010937
# 15384      0.000000          0.000000
# 15385      0.000000          0.000000
# 15386      0.000000          0.000000
#
# [15387 rows x 14 columns]

# %%
# example for one lyrics
lst = df["lyrics"][0].split("\n") # split lyrics into lines
num_lines = len(lst) # number of lines
token_lines = [word_tokenize(s) for s in lst]
scores_for_sent = {}
weighted_sev_score_lyrics = 0  # value for averaged sev_score over the whole lyrics

for i,line in enumerate(token_lines):
    num_of_words = len(line) # number of words in one line
    sev_score_line = 0  # sev score for one line
    for el in line:
        if el in slurs:
            sev_score_line += float(slurs[el])  
    weighted_sev_score = sev_score_line/num_of_words   # weighted sev score for one line
    scores_for_sent[i] = {"num_of_words": num_of_words, "sev_score_per_line": sev_score_line, "weighted_sev_score": weighted_sev_score}
    weighted_sev_score_lyrics += weighted_sev_score # we sum all the weighted sev scores for each line

result = weighted_sev_score_lyrics/num_lines # get the intended value (average sev score for lyrics divided by number of lines
pprint.pprint(scores_for_sent)
print("THE RESULT IS: ", result)
# Out:
# {0: {'num_of_words': 14,
#      'sev_score_per_line': 4.4,
#      'weighted_sev_score': 0.31428571428571433},
#  1: {'num_of_words': 14, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  2: {'num_of_words': 9,
#      'sev_score_per_line': 1.0,
#      'weighted_sev_score': 0.1111111111111111},
#  3: {'num_of_words': 14, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  4: {'num_of_words': 6, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  5: {'num_of_words': 19,
#      'sev_score_per_line': 2.8,
#      'weighted_sev_score': 0.14736842105263157},
#  6: {'num_of_words': 10,
#      'sev_score_per_line': 1.4,
#      'weighted_sev_score': 0.13999999999999999},
#  7: {'num_of_words': 6, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  8: {'num_of_words': 12, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  9: {'num_of_words': 12, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  10: {'num_of_words': 21,
#       'sev_score_per_line': 2.6,
#       'weighted_sev_score': 0.12380952380952381},
#  11: {'num_of_words': 6, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  12: {'num_of_words': 12, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  13: {'num_of_words': 13, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  14: {'num_of_words': 23, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  15: {'num_of_words': 10, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  16: {'num_of_words': 13, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  17: {'num_of_words': 13, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  18: {'num_of_words': 13,
#       'sev_score_per_line': 2.8,
#       'weighted_sev_score': 0.21538461538461537},
#  19: {'num_of_words': 10, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  20: {'num_of_words': 13, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  21: {'num_of_words': 12,
#       'sev_score_per_line': 1.4,
#       'weighted_sev_score': 0.11666666666666665},
#  22: {'num_of_words': 12,
#       'sev_score_per_line': 1.4,
#       'weighted_sev_score': 0.11666666666666665},
#  23: {'num_of_words': 7, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  24: {'num_of_words': 8, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  25: {'num_of_words': 11, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  26: {'num_of_words': 10, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  27: {'num_of_words': 10, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  28: {'num_of_words': 10, 'sev_score_per_line': 0, 'weighted_sev_score': 0.0},
#  29: {'num_of_words': 13,
#       'sev_score_per_line': 2.0,
#       'weighted_sev_score': 0.15384615384615385}}
# THE RESULT IS:  0.047971295760769445
